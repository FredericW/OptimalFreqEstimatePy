# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# set key parameters
data_type="EXPONENTIAL" 
d = 16
est_type="sw"
test_type='portions'
total_repeat=50
portion = 0.5

filename = 'data/result_%s_%s_%d_%s(%.2f,%d).csv' % (data_type,
                        est_type, d,test_type, portion, total_repeat)
result = pd.read_csv(filename)
eps_grid = np.asarray(result['eps_grid'])
var_aaa = np.asarray(result['var_aaa'])
var_est = np.asarray(result['var_est'])
wass_aaa = np.asarray(result['wass_aaa'])
wass_est = np.asarray(result['wass_est'])

plt.figure(figsize=(5,3))
plt.plot(eps_grid,var_aaa,label = 'aaa w. %s'%(est_type),
        linewidth='2.0')
plt.plot(eps_grid, var_est,label = est_type,
        linewidth='2.0',
        linestyle='dashed')
plt.xlabel('epsilon')
plt.ylabel('variance')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,3))
plt.plot(eps_grid,wass_aaa,label = 'aaa w. %s'%(est_type),
        linewidth='2.0')
plt.plot(eps_grid, wass_est,label = est_type,
        linewidth='2.0',
        linestyle='dashed')
plt.xlabel('epsilon')
plt.ylabel('Wass Distance')
plt.legend()
plt.grid()
plt.show()
